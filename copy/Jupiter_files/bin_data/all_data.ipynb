# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/home/aamin/files/marketing/copy/reports_data/all_reports_data.csv")
# Out:
# /home/aamin/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3106: DtypeWarning: Columns (6,8,13,14,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data[["Broadcast name","Delivered Date"]].value_counts().to_csv("boradcast_name.csv")

# %%
data[data["category"] == "leads"]["Broadcast name"].value_counts()
# Out:
# DTSS Delhi 1211                         40918
# ISS Mumbai 1211                         38244
# ISS Mumbai 1311                         38244
# ISS Mumbai 1411                         38244
# Big C Hyderabad 1211                    37892
# Hinduja Global Solutions 1211           37819
# FinPedia 0806                           16606
# FinPedia 0906                           16598
# Communication_Marketing_Dropout_0301    11146
# FinPedia 0106                            8385
# RNR Cases 0206                           6157
# RNR Cases 0106                           5812
# RNR Cases 3006                           5166
# UDS Delhi 1311                           4935
# UDS Delhi 1411                           4935
# RNR Cases 2806                           4928
# RNR Cases 3105                           4808
# RNR Cases 2406                           4687
# RNR Cases 22062022                       4577
# RNR Cases 2206                           4471
# ...

# %%
data[data["Broadcast name"] == "FinPedia 0906"]
# Out:
#         Unnamed: 0  Unnamed: 0.1  Broadcast ID Broadcast name  Mobile number  \
# 1626          1626          1711          4920  FinPedia 0906     8779117822
# 1627          1627          1712          4920  FinPedia 0906     9967284368
# 1628          1628          1713          4920  FinPedia 0906     9092061008
# 1629          1629          1714          4920  FinPedia 0906     9450505438
# 1630          1630          1715          4920  FinPedia 0906     8698852501
# ...            ...           ...           ...            ...            ...
# 290478      290478        297235          4920  FinPedia 0906     8919386121
# 290479      290479        297236          4920  FinPedia 0906     9785831629
# 290480      290480        297237          4920  FinPedia 0906     8097663319
# 290481      290481        297238          4920  FinPedia 0906     8791616620
# 290482      290482        297239          4920  FinPedia 0906     9731932968
#
# ...
